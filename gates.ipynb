# %%
from qiskit import *

# %%
circuit =QuantumCircuit(1,1)
circuit.x(0)
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit,backend=simulator).result()
state_vector = result.get_statevector()
print(state_vector)
circuit.draw(output='mpl')
# Out:
# [0.+0.j 1.+0.j]

# %%
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(state_vector)

# %%
circuit.measure([0],[0])
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit,backend=simulator).result()
count = result.get_counts()
from qiskit.visualization import plot_histogram
plot_histogram(count)

# %%
circuit = QuantumCircuit(1,1)
circuit.x(0)
simuilator = Aer.get_backend('unitary_simulator')
result = execute(circuit,backend=simuilator).result()
unitary = result.get_unitary()
print(unitary)
# Out:
# [[0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j]]

# %%
circuit = QuantumCircuit(1,1)
#circuit.x(0)
circuit.h(0)
circuit.x(0)
circuit.h(0)
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit,simulator).result()
state_vector = result.get_statevector()
print(state_vector)
circuit.draw(output='mpl')
# Out:
# [1.-6.123234e-17j 0.+6.123234e-17j]

# %%
plot_bloch_multivector(state_vector)

# %%
circuit = QuantumCircuit(1,1)
circuit.h(0)
circuit.y(0)
circuit.z(0)
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit,simulator).result()
state_vector = result.get_statevector()
print(state_vector)
circuit.draw(output='mpl')
# Out:
# [ 0.-0.70710678j -0.-0.70710678j]

# %%
plot_bloch_multivector(state_vector)

# %%
circuit = QuantumCircuit(1,1)
circuit.x(0)
circuit.h(0)
#circuit.x(0)
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit,simulator).result()
state_vector = result.get_statevector()
state_vector
#circuit.draw(output='mpl')
# Out:
# array([ 0.70710678-8.65956056e-17j, -0.70710678+8.65956056e-17j])

# %%
plot_bloch_multivector(state_vector)

# %%
circuit = QuantumCircuit(1,1)
circuit.h(0)
circuit.z(0)
circuit.h(0)
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit,simulator).result()
state_vector = result.get_statevector()
print(state_vector)
circuit.draw(output='mpl')
# Out:
# [0.+6.123234e-17j 1.-6.123234e-17j]

# %%
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(state_vector)

# %%
from math import sqrt
qc = QuantumCircuit(1,1)
initial_state = [0.j+1/sqrt(2),0.j-1/sqrt(2)]
qc.initialize(initial_state,0)
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc,simulator).result()
state_vector = result.get_statevector()
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(state_vector)

# %%
qc.draw(output='mpl')

# %%
qc.measure(0,0)
simulator = Aer.get_backend('qasm_simulator')
result = execute(qc,backend=simulator).result()
count = result.get_counts(qc)
from qiskit.tools.visualization import plot_histogram
plot_histogram(count)

# %%
print(state_vector)
# Out:
# [ 0.70710678+0.j -0.70710678+0.j]

# %%
qc = QuantumCircuit(1,1)
#qc.x(0)
qc.h(0)
qc.draw(output='mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc,backend=simulator).result()
state_vector = result.get_statevector()
print(state_vector)
plot_bloch_multivector(state_vector)
# Out:
# [0.70710678+0.j 0.70710678+0.j]
